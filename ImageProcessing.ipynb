# %% [markdown]
# # import sysytem libraries

# %%
import os
import warnings
warnings.simplefilter('ignore')

# %% [markdown]
# # importing DataHandling Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Importing DataVisualization Library

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from skimage.io import imread, imshow
from skimage.transform import resize
from skimage.color import rgb2gray

# %% [markdown]
# # B1 setting working directory

# %%
atharvaa= os.listdir("C:/Users/Bogeyman/Downloads/I P/atharvaa")

# %%
arjun= os.listdir("C:/Users/Bogeyman/Downloads/I P/arjun")

# %%
arnold= os.listdir("C:/Users/Bogeyman/Downloads/I P/arnold")

# %%
limit = 60
atharvaaimages = [None]*limit
j=0

for i in atharvaa:
    if(j<limit):
        atharvaaimages[j]=imread("C:/Users/Bogeyman/Downloads/I P/atharvaa/"+i)
        j+=1
    else:
        break

# %%
limit = 60
arjunimages = [None]*limit
j=0

for i in arjun:
    if(j<limit):
        arjunimages[j]=imread("C:/Users/Bogeyman/Downloads/I P/arjun/"+i)
        j+=1
    else:
        break

# %%
limit = 60
arnoldimages = [None]*limit
j=0

for i in arnold:
    if(j<limit):
        arnoldimages[j]=imread("C:/Users/Bogeyman/Downloads/I P/arnold/"+i)
        j+=1
    else:
        break

# %%
imshow(atharvaaimages[15])

# %%
imshow(arjunimages[15])

# %%
imshow(arnoldimages[9])

# %%
atharvaa_gray= [None]*limit
j=0

for i in atharvaa:
    if(j<limit):
        atharvaa_gray[j]=rgb2gray(atharvaaimages[j])
        j+=1
    else:
        break

# %%
 arjun_gray= [None]*limit
 j=0
 
 for i in arjun:
     if(j<limit):
         arjun_gray[j]=rgb2gray(arjunimages[j])
         j+=1
     else:
         break

# %%
arnold_gray= [None]*limit
j=0

for i in arnold:
    if(j<limit):
        arnold_gray[j]=rgb2gray(arnoldimages[j])
        j+=1
    else:
        break

# %%
imshow(atharvaa_gray[0])

# %%
imshow(arjun_gray[6])

# %%
imshow(arnold_gray[7])

# %%
atharvaa_gray[6].shape
# Out:
# (1080, 1080)

# %%
arjun_gray[7].shape
# Out:
# (960, 1440)

# %%
arnold_gray[4].shape
# Out:
# (900, 600)

# %%
for j in range(60):
    dm = atharvaa_gray[j]
    atharvaa_gray[j]=resize(dm,(512,512))

# %%
for j in range(60):
    ky = arjun_gray[j]
    arjun_gray[j]=resize(ky,(512,512))

# %%
for j in range(60):
    sd = arnold_gray[j]
    arnold_gray[j]=resize(sd,(512,512))

# %%
imshow(atharvaa_gray[6])

# %%
imshow(arjun_gray[4])

# %%
imshow(arnold_gray[6])

# %% [markdown]
# # atharvaa

# %%
len_of_image_atharvaa = len(atharvaa_gray)

# %%
len_of_image_atharvaa
# Out:
# 60

# %%
image_size_atharvaa = atharvaa_gray[1].shape

# %%
image_size_atharvaa
# Out:
# (512, 512)

# %%
flatten_size_atharvaa = image_size_atharvaa[0]*image_size_atharvaa[1]

# %%
flatten_size_atharvaa
# Out:
# 262144

# %%
for i in range(len_of_image_atharvaa):
    atharvaa_gray[i]= np.ndarray.flatten(atharvaa_gray[i]).reshape(flatten_size_atharvaa,1)

# %%
atharvaa_gray=np.dstack(atharvaa_gray)

# %%
atharvaa_gray.shape
# Out:
# (262144, 1, 60)

# %%
atharvaa_gray=np.rollaxis(atharvaa_gray, axis=2,start=0)
atharvaa_gray.shape
# Out:
# (60, 262144, 1)

# %%
atharvaa_gray = atharvaa_gray.reshape(len_of_image_atharvaa,flatten_size_atharvaa)
atharvaa_gray.shape
# Out:
# (60, 262144)

# %%
atharvaa_data = pd.DataFrame(atharvaa_gray)
atharvaa_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.855988  0.855988  0.855988  0.855988  0.855988  0.855988  0.855988
# 1   0.408214  0.405871  0.405970  0.412334  0.418080  0.414376  0.414885
# 2   0.972549  0.972549  0.972549  0.972549  0.972549  0.972549  0.972549
# 3   0.052883  0.056557  0.060272  0.063845  0.067474  0.072588  0.078845
# 4   0.810333  0.816137  0.814668  0.809153  0.806886  0.805733  0.803341
# 5   0.448967  0.448967  0.448967  0.448967  0.448971  0.452881  0.452888
# 6   0.859113  0.802150  0.644514  0.634693  0.746697  0.862160  0.856763
# 7   0.737255  0.737255  0.737255  0.738239  0.745081  0.745098  0.745099
# 8   0.995208  0.995208  0.995208  0.995208  0.995208  0.995054  0.994649
# 9   0.324989  0.324989  0.325306  0.326831  0.326882  0.327314  0.334397
# 10  0.787001  0.787001  0.785804  0.780051  0.779857  0.779857  0.779857
# 11  0.698620  0.698620  0.698620  0.698620  0.698620  0.698620  0.698620
# ...

# %%
atharvaa_data["label"]="atharvaa murali"
atharvaa_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.855988  0.855988  0.855988  0.855988  0.855988  0.855988  0.855988
# 1   0.408214  0.405871  0.405970  0.412334  0.418080  0.414376  0.414885
# 2   0.972549  0.972549  0.972549  0.972549  0.972549  0.972549  0.972549
# 3   0.052883  0.056557  0.060272  0.063845  0.067474  0.072588  0.078845
# 4   0.810333  0.816137  0.814668  0.809153  0.806886  0.805733  0.803341
# 5   0.448967  0.448967  0.448967  0.448967  0.448971  0.452881  0.452888
# 6   0.859113  0.802150  0.644514  0.634693  0.746697  0.862160  0.856763
# 7   0.737255  0.737255  0.737255  0.738239  0.745081  0.745098  0.745099
# 8   0.995208  0.995208  0.995208  0.995208  0.995208  0.995054  0.994649
# 9   0.324989  0.324989  0.325306  0.326831  0.326882  0.327314  0.334397
# 10  0.787001  0.787001  0.785804  0.780051  0.779857  0.779857  0.779857
# 11  0.698620  0.698620  0.698620  0.698620  0.698620  0.698620  0.698620
# ...

# %% [markdown]
# # arjun

# %%
len_of_image_arjun = len(arjun_gray)

# %%
len_of_image_arjun
# Out:
# 60

# %%
image_size_arjun = arjun_gray[1].shape

# %%
image_size_arjun
# Out:
# (512, 512)

# %%
flatten_size_arjun = image_size_arjun[0]*image_size_arjun[1]

# %%
flatten_size_arjun
# Out:
# 262144

# %%
for i in range(len_of_image_arjun):
    arjun_gray[i]=np.ndarray.flatten(arjun_gray[i]).reshape(flatten_size_arjun,1)

# %%
arjun_gray=np.dstack(arjun_gray)

# %%
arjun_gray.shape
# Out:
# (262144, 1, 60)

# %%
arjun_gray=np.rollaxis(arjun_gray, axis=2,start=0)
arjun_gray.shape
# Out:
# (60, 262144, 1)

# %%
arjun_gray = arjun_gray.reshape(len_of_image_arjun,flatten_size_arjun)
arjun_gray.shape
# Out:
# (60, 262144)

# %%
arjun_data = pd.DataFrame(arjun_gray)
arjun_data
# Out:
#       0         1         2         3         4         5         6       \
# 0   0.191526  0.191526  0.191526  0.191526  0.191526  0.191526  0.191526
# 1   0.195487  0.199435  0.202889  0.202809  0.207317  0.209490  0.206084
# 2   0.554387  0.635110  0.357234  0.159136  0.271495  0.222319  0.168661
# 3   0.890708  0.892825  0.896960  0.903524  0.907411  0.910884  0.915855
# 4   0.586529  0.590716  0.594149  0.594708  0.598318  0.601345  0.600118
# 5   0.603164  0.603164  0.603164  0.603164  0.603164  0.603164  0.603164
# 6   0.223873  0.223873  0.225188  0.231021  0.227115  0.225585  0.230974
# 7   0.213675  0.234258  0.261194  0.319064  0.506945  0.504845  0.464160
# 8   0.581449  0.655874  0.673659  0.649865  0.645947  0.650299  0.642003
# 9   0.394767  0.271806  0.201307  0.174731  0.179361  0.180858  0.167671
# 10  0.171303  0.163657  0.155143  0.153055  0.153006  0.152330  0.151481
# 11  0.820434  0.824930  0.828963  0.830963  0.830998  0.832065  0.834878
# ...

# %%
arjun_data["label"]="arjun das"
arjun_data
# Out:
#            0         1         2         3         4         5         6  \
# 0   0.191526  0.191526  0.191526  0.191526  0.191526  0.191526  0.191526
# 1   0.195487  0.199435  0.202889  0.202809  0.207317  0.209490  0.206084
# 2   0.554387  0.635110  0.357234  0.159136  0.271495  0.222319  0.168661
# 3   0.890708  0.892825  0.896960  0.903524  0.907411  0.910884  0.915855
# 4   0.586529  0.590716  0.594149  0.594708  0.598318  0.601345  0.600118
# 5   0.603164  0.603164  0.603164  0.603164  0.603164  0.603164  0.603164
# 6   0.223873  0.223873  0.225188  0.231021  0.227115  0.225585  0.230974
# 7   0.213675  0.234258  0.261194  0.319064  0.506945  0.504845  0.464160
# 8   0.581449  0.655874  0.673659  0.649865  0.645947  0.650299  0.642003
# 9   0.394767  0.271806  0.201307  0.174731  0.179361  0.180858  0.167671
# 10  0.171303  0.163657  0.155143  0.153055  0.153006  0.152330  0.151481
# 11  0.820434  0.824930  0.828963  0.830963  0.830998  0.832065  0.834878
# ...

# %% [markdown]
# # arnold

# %%
len_of_image_arnold = len(arnold_gray)

# %%
len_of_image_arnold
# Out:
# 60

# %%
image_size_arnold = arnold_gray[1].shape

# %%
image_size_arnold
# Out:
# (262144,)

# %%
flatten_size_arnold = image_size_arnold[0]*image_size_arnold[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8316\1701375992.py in <module>
# ----> 1 flatten_size_arnold = image_size_arnold[0]*image_size_arnold[1]
#
# IndexError: tuple index out of range

# %%
flatten_size_arnold

# %%
for i in range(len_of_image_arnold):
    arnold_gray[i]= np.ndarray.flatten(arnold_gray[i]).reshape(flatten_size_arnold,1)

# %%
arnold_gray=np.dstack(arnold_gray)

# %%
arnold_gray.shape

# %%
arnold_gray=np.rollaxis(arnold_gray, axis=2,start=0)
arnold_gray.shape

# %%
arnold_gray = arnold_gray.reshape(len_of_image_arnold,flatten_size_arnold)
arnold_gray.shape

# %%
arnold_data = pd.DataFrame(arnold_gray)
arnold_data

# %%
arnold_data["label"]="arnold schwarzenegger"
arnold_data

# %%
actor_1=pd.concat([atharvaa_data,arjun_data])
actor=pd.concat([actor_1,arnold_data])

# %%
from sklearn.utils import shuffle
Faces_indexed=shuffle(actor).reset_index()
Faces_indexed
# Out:
#      index         0         1         2         3         4         5  \
# 0       10  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1        8  0.995208  0.995208  0.995208  0.995208  0.995208  0.995054
# 2        9  0.324989  0.324989  0.325306  0.326831  0.326882  0.327314
# 3       23  0.482818  0.482817  0.480546  0.470728  0.463830  0.452313
# 4       32  0.035251  0.035251  0.035251  0.035251  0.035251  0.035251
# ..     ...       ...       ...       ...       ...       ...       ...
# 175     57  0.745999  0.749295  0.749906  0.749957  0.753828  0.757742
# 176     20  0.084302  0.084302  0.082043  0.080381  0.076459  0.076459
# 177     34  0.178624  0.165211  0.199501  0.234694  0.261259  0.261878
# 178     22  0.038401  0.048921  0.053465  0.052714  0.065719  0.069251
# 179     42  0.991889  0.991889  0.991889  0.991889  0.991889  0.991889
#
#             6         7         8  ...    262135    262136    262137  \
# ...

# %%
Faces_indexed=Faces_indexed.drop(['index'],axis=1)
Faces_indexed
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.003922  0.003922  0.003922  0.003922  0.003922  0.003922  0.003922
# 1    0.995208  0.995208  0.995208  0.995208  0.995208  0.995054  0.994649
# 2    0.324989  0.324989  0.325306  0.326831  0.326882  0.327314  0.334397
# 3    0.482818  0.482817  0.480546  0.470728  0.463830  0.452313  0.459474
# 4    0.035251  0.035251  0.035251  0.035251  0.035251  0.035251  0.034797
# ..        ...       ...       ...       ...       ...       ...       ...
# 175  0.745999  0.749295  0.749906  0.749957  0.753828  0.757742  0.757749
# 176  0.084302  0.084302  0.082043  0.080381  0.076459  0.076459  0.079507
# 177  0.178624  0.165211  0.199501  0.234694  0.261259  0.261878  0.603339
# 178  0.038401  0.048921  0.053465  0.052714  0.065719  0.069251  0.085009
# 179  0.991889  0.991889  0.991889  0.991889  0.991889  0.991889  0.991890
#
#             7         8         9  ...    262135    262136    262137  \
# ...

# %%
x=Faces_indexed.values[:,:-1]

# %%
y=Faces_indexed.values[:,-1]

# %%
x
# Out:
# array([[0.00392156862745098, 0.0039215686274509795, 0.00392156862745098,
#         ..., 0.00392156862745098, 0.00392156862745098,
#         0.00392156862745098],
#        [0.9952082352941176, 0.9952082352941175, 0.9952082352941175, ...,
#         0.36710890460688134, 0.3452477772532955, 0.35369824471374783],
#        [0.32498855030966484, 0.32498858555613375, 0.32530595977706483,
#         ..., 0.30993692347185897, 0.3146593706467221, 0.3199477916162247],
#        ...,
#        [0.1786240595118499, 0.16521068462951222, 0.19950148923006544,
#         ..., 0.23026081039005547, 0.22988511414358256,
#         0.22248443595667128],
#        [0.038401477348622794, 0.048920709968875827, 0.053465233864723474,
#         ..., 0.5617805378599273, 0.6053625483394056, 0.6101902296697381],
#        [0.9918890196078434, 0.9918890196078434, 0.9918890196078434, ...,
#         0.4105980972778246, 0.3961843177343495, 0.42736353234161817]],
#       dtype=object)

# %%
y
# Out:
# array(['arnold schwarzenegger', 'atharvaa murali', 'atharvaa murali',
#        'arjun das', 'arnold schwarzenegger', 'atharvaa murali',
#        'arnold schwarzenegger', 'arjun das', 'arjun das', 'arjun das',
#        'arnold schwarzenegger', 'arjun das', 'arnold schwarzenegger',
#        'atharvaa murali', 'arnold schwarzenegger', 'arjun das',
#        'atharvaa murali', 'arjun das', 'atharvaa murali',
#        'arnold schwarzenegger', 'atharvaa murali',
#        'arnold schwarzenegger', 'arjun das', 'arjun das', 'arjun das',
#        'atharvaa murali', 'atharvaa murali', 'arjun das', 'arjun das',
#        'arjun das', 'arnold schwarzenegger', 'arnold schwarzenegger',
#        'arnold schwarzenegger', 'arjun das', 'arnold schwarzenegger',
#        'arjun das', 'atharvaa murali', 'atharvaa murali',
#        'arnold schwarzenegger', 'atharvaa murali', 'arjun das',
#        'arjun das', 'arjun das', 'arnold schwarzenegger',
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=0)

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(x_train,y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(x_test)
y_pred
# Out:
# array(['arjun das', 'arjun das', 'atharvaa murali',
#        'arnold schwarzenegger', 'arnold schwarzenegger', 'arjun das',
#        'arjun das', 'arnold schwarzenegger', 'arnold schwarzenegger',
#        'arjun das', 'arjun das', 'atharvaa murali',
#        'arnold schwarzenegger', 'atharvaa murali', 'atharvaa murali',
#        'arjun das', 'atharvaa murali', 'arjun das', 'atharvaa murali',
#        'arnold schwarzenegger', 'atharvaa murali', 'arjun das',
#        'arnold schwarzenegger', 'arnold schwarzenegger', 'arjun das',
#        'atharvaa murali', 'arjun das', 'arnold schwarzenegger',
#        'atharvaa murali', 'arnold schwarzenegger', 'atharvaa murali',
#        'atharvaa murali', 'arjun das', 'arjun das', 'atharvaa murali',
#        'arjun das'], dtype=object)

# %%
for i in (np.random.randint(0,6,4)):
    predicted_images = (np.reshape(x_test[i],(512,512)).astype(np.float64))
    plt.title('predicted label: {}'.format(y_pred[i]))
    plt.imshow(predicted_images,interpolation='nearest',cmap='gray')
    plt.show()

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[12,  0,  0],
#        [ 0,  7,  3],
#        [ 2,  3,  9]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7777777777777778
